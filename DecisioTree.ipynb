# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('RTA_preprocessed_encoded.csv')

# %%
data.head()
# Out:
#    Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                   0              1                  0
# 1                   1              1                  4
# 2                   0              1                  4
# 3                   0              1                  4
# 4                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                2
# 1                        0                   3                1
# 2                        0                   0                3
# 3                        0                   2                1
# 4                        0                   1                5
#
#    Area_accident_occured  Lanes_or_Medians  Types_of_Junction  \
# 0                      8                 6                  1
# 1                      4                 5                  1
# 2                      7                 2                  1
# 3                      4                 2                  6
# 4                      2                 2                  6
#
#    Road_surface_type  Light_conditions  Weather_conditions  Type_of_collision  \
# 0                  0                 3                   2                  3
# 1                  0                 3                   2                  7
# 2                  0                 3                   2                  2
# 3                  2                 0                   2                  7
# 4                  0                 0                   2                  7
#
#    Number_of_vehicles_involved  Vehicle_movement  Pedestrian_movement  \
# 0                            2                 2                    5
# 1                            2                 2                    5
# 2                            2                 2                    5
# 3                            2                 2                    5
# 4                            2                 2                    5
#
#    Cause_of_accident  Accident_severity
# 0                  9                  2
# 1                 16                  2
# 2                  0                  1
# 3                  1                  2
# 4                 16                  2

# %%
x  = data.drop('Accident_severity',axis=1)
y = data['Accident_severity']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array([2, 2, 2, ..., 2, 2, 2], shape=(1674,))

# %%
print(accuracy_score(y_test,pred))
print(classification_report(y_test, pred))
# Out:
# 0.7132616487455197
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        20
#            1       0.13      0.17      0.15       226
#            2       0.85      0.81      0.83      1428
#
#     accuracy                           0.71      1674
#    macro avg       0.33      0.33      0.33      1674
# weighted avg       0.74      0.71      0.73      1674

# %%
plt.figure(figsize=(20,10))
plot_tree(model, feature_names=x.columns, class_names=["0","1","2"], filled=True, max_depth=3)
plt.show()
